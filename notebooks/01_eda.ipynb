# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from src.data.gcp_utils import read_config
from src.data.load_dataset import prepare_dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       1 import sys
#       2 import os
#       3 sys.path.append(os.path.abspath(".."))
#       4
# ----> 5 from src.data.gcp_utils import read_config
#       6 from src.data.load_dataset import prepare_dataset
#
# File c:\Users\moreyramaida\OneDrive - Caja de Seguros S.A\Escritorio\credit-scorecard\src\data\gcp_utils.py:1
# ----> 1 from google.cloud import storage
#       2 from google.cloud import bigquery
#       3 from datetime import datetime, timedelta
#
# ModuleNotFoundError: No module named 'google'

# %%
cfg = read_config()

df = prepare_dataset(cfg)

df.head()
